# %%
#Act #2 Ejercicios Basicos en Phyton
#Uriel Alejandro Alanis Sanchez   mat: 1918324
#hora: N1-N3

# %%
#primer ejercicio
nombre= input("¿cual es tu nombre?")
a=["Ana"]
if str(nombre) == ("Ana"):
  print("Hola")
else:
    if str(nombre) == ("Pedro"):
      print("Hola")
    else:
      if str(nombre) == ("Juan"):
        print("Hola")
      else:
        print("hola "+ nombre+"!")
# Out:
# ¿cual es tu nombre?uriel
# hola uriel!

# %%
#segundo ejercicio
conteo=["1","2","3","4","5"]
print(conteo)
print(list(reversed(conteo)))
# Out:
# ['1', '2', '3', '4', '5']
# ['5', '4', '3', '2', '1']

# %%
#tercer ejercicio
marco=[
"####################",
"#         hola     #",
"#          a       #",
"#        todos     #",
"#       miren      #",
"#        esto      #",
"####################"]
for x in marco:
  print(x)
# Out:
# ####################
# #         hola     #
# #          a       #
# #        todos     #
# #       miren      #
# #        esto      #
# ####################
